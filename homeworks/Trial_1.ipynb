# %%
print("Mouna")
# Out:
# Mouna

# %%
print(7+2)
# Out:
# 9

# %%
if 7 > 8:
    print("hey")
else:
    print("Mouna")
# Out:
# Mouna

# %%
def add_num(n, m):
    print(n + m)


add_num(5,6)
# Out:
# 11
